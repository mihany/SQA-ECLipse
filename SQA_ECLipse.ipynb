# %% [markdown]
# <a href="https://colab.research.google.com/github/mihany/SQA-ECLipse/blob/main/SQA_ECLipse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read Data

# %%
from google.colab import drive
import pandas as pd 

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv("/content/drive/MyDrive/Eclipse/Eclipse20_GAP10_BURST10_incl_bugs.csv")

# %%
data.head()
# Out:
#                                             filename  ...  NORM_Modifier
# 0  /org.eclipse.pde.ui/src/org/eclipse/pde/intern...  ...       0.090909
# 1  /org.eclipse.ui.externaltools/External Tools/o...  ...       0.026316
# 2  /org.eclipse.jdt.ui/ui/org/eclipse/jdt/interna...  ...       0.041667
# 3  /org.eclipse.ui/Eclipse JFace Text/org/eclipse...  ...       0.058442
# 4  /org.eclipse.jdt.core/compiler/org/eclipse/jdt...  ...       0.069767
#
# [5 rows x 225 columns]

# %%
pre_02= data["pre"]
post_02= data["NumberOfDefects"]

# %%
pre_02
# Out:
# 0       0
# 1       5
# 2       1
# 3       0
# 4       0
#        ..
# 6723    2
# 6724    1
# 6725    0
# 6726    1
# 6727    0
# Name: pre, Length: 6728, dtype: int64

# %% [markdown]
# # Unified

# %%
Unified_V20_class = pd.read_csv("/content/drive/MyDrive/Eclipse/Unified/updated-20-eclipse-files.csv") 
Unified_V21_class = pd.read_csv("/content/drive/MyDrive/Eclipse/Unified/updated-21-eclipse-files.csv") 
Unified_V30_class = pd.read_csv("/content/drive/MyDrive/Eclipse/Unified/updated-30-eclipse-files.csv") 

Unified_V20_Pack = pd.read_csv("/content/drive/MyDrive/Eclipse/Unified/updated-20-eclipse-packages.csv") 
Unified_V21_Pack = pd.read_csv("/content/drive/MyDrive/Eclipse/Unified/updated-21-eclipse-packages.csv") 
Unified_V30_Pack = pd.read_csv("/content/drive/MyDrive/Eclipse/Unified/updated-30-eclipse-packages.csv") 

Unified_V20_class.drop(Unified_V20_class.tail(1).index,inplace=True)
Unified_V21_class.drop(Unified_V21_class.tail(1).index,inplace=True)
Unified_V30_class.drop(Unified_V30_class.tail(1).index,inplace=True)

Unified_V20_Pack.drop(Unified_V20_Pack.tail(1).index,inplace=True)
Unified_V21_Pack.drop(Unified_V21_Pack.tail(1).index,inplace=True)
Unified_V30_Pack.drop(Unified_V30_Pack.tail(1).index,inplace=True)

# %%
PlugIn_20_class=Unified_V20_class["plugin"]
FileName_20_class=Unified_V20_class["filename"]
PlugIn_20_Pack=Unified_V20_Pack["plugin"]
PackName_20_Pack=Unified_V20_Pack["packagename"]

PlugIn_21_class=Unified_V21_class["plugin"]
FileName_21_class=Unified_V21_class["filename"]
PlugIn_21_Pack=Unified_V21_Pack["plugin"]
PackName_21_Pack=Unified_V21_Pack["packagename"]

PlugIn_30_class=Unified_V30_class["plugin"]
FileName_30_class=Unified_V30_class["filename"]
PlugIn_30_Pack=Unified_V30_Pack["plugin"]
PackName_30_Pack=Unified_V30_Pack["packagename"]

# %%
print("--------------------------------------------------------")
print("                     Version 2.0")
print("--------------------------------------------------------")
print("                     Package")
print("                  -------------")
print(PlugIn_20_class.head())
print(FileName_20_class.head())
print("")
print("                  |   Class   |")
print("                  -------------")
print(PlugIn_20_Pack.head())
print(PackName_20_Pack.head())
print("")
print("")

print("--------------------------------------------------------")
print("                     Version 2.1")
print("--------------------------------------------------------")
print("                     Package")
print("                  -------------")
print(PlugIn_21_class.head())
print(FileName_21_class.head())
print("")
print("                  |   Class   |")
print("                  -------------")
print(PlugIn_21_Pack.head())
print(PackName_21_Pack.head())
print("")
print("")


print("--------------------------------------------------------")
print("                     Version 3.0")
print("--------------------------------------------------------")
print("                     Package")
print("                  -------------")
print(PlugIn_30_class.head())
print(FileName_30_class.head())
print("")
print("                  |   Class   |")
print("                  -------------")
print(PlugIn_30_Pack.head())
print(PackName_30_Pack.head())
print("")
print("")
# Out:
# --------------------------------------------------------
#                      Version 2.0
# --------------------------------------------------------
#                      Package
#                   -------------
# 0    org.eclipse.jdt.junit
# 1    org.eclipse.jdt.junit
# 2    org.eclipse.jdt.junit
# 3    org.eclipse.jdt.junit
# 4    org.eclipse.jdt.junit
# Name: plugin, dtype: object
# 0    /org.eclipse.jdt.junit/src/org/eclipse/jdt/int...
# 1    /org.eclipse.jdt.junit/src/org/eclipse/jdt/int...
# 2    /org.eclipse.jdt.junit/src/org/eclipse/jdt/int...
# 3    /org.eclipse.jdt.junit/src/org/eclipse/jdt/int...
# 4    /org.eclipse.jdt.junit/src/org/eclipse/jdt/int...
# Name: filename, dtype: object
#
#                   |   Class   |
#                   -------------
# 0    org.eclipse.jdt.junit
# 1    org.eclipse.jdt.junit
# 2    org.eclipse.jdt.junit
# 3    org.eclipse.jdt.junit
# 4    org.eclipse.jdt.junit
# Name: plugin, dtype: object
# ...

# %%
Unified_V20_class

# %%
Pre_20_class=Unified_V20_class["pre"]        # Defects before 6 months of release
Post_20_class=Unified_V20_class["post"]      # Defects after 6 months of release
FOUT_20_class=Unified_V20_class["FOUT_avg"]  # fan out (method calls)
MLOC_20_class=Unified_V20_class["MLOC_avg"]  # method line of code
NOM_20_class=Unified_V20_class["NOM_avg"]    # methods
NSM_20_class=Unified_V20_class["NSM_avg"]    # static methods
NOT_20_class=Unified_V20_class["NOT"]        # classes
NOI_20_class=Unified_V20_class["NOI"]        # Interfaces
TLOC_20_class=Unified_V20_class["TLOC"]      # total lines of code
ACD_20_class=Unified_V20_class["ACD"]        # Anonymous type declarations
VG_20_class=Unified_V20_class["VG_avg"]       # VG

Pre_20_Pack = Unified_V20_Pack["pre"]        # Defects before 6 months of release
Post_20_Pack=Unified_V20_Pack["post"]      # Defects after 6 months of release
FOUT_20_Pack=Unified_V20_Pack["FOUT_avg"]  # fan out (method calls)
MLOC_20_Pack=Unified_V20_Pack["MLOC_avg"]  # method line of code
NOM_20_Pack=Unified_V20_Pack["NOM_avg"]    # methods
NSM_20_Pack=Unified_V20_Pack["NSM_avg"]    # static methods
NOCU_20_Pack=Unified_V20_Pack["NOCU"]       #Number of files (compilation units)
VG_20_Pack=Unified_V20_Pack["VG_avg"]       # VG

# %%
Pre_21_class=Unified_V21_class["pre"]        # Defects before 6 months of release
Post_21_class=Unified_V21_class["post"]      # Defects after 6 months of release
FOUT_21_class=Unified_V21_class["FOUT_avg"]  # fan out (method calls)
MLOC_21_class=Unified_V21_class["MLOC_avg"]  # method line of code
NOM_21_class=Unified_V21_class["NOM_avg"]    # methods
NSM_21_class=Unified_V21_class["NSM_avg"]    # static methods
NOT_21_class=Unified_V21_class["NOT"]        # classes
NOI_21_class=Unified_V21_class["NOI"]        # Interfaces
TLOC_21_class=Unified_V21_class["TLOC"]      # total lines of code
ACD_21_class=Unified_V21_class["ACD"]        # Anonymous type declarations
VG_21_class=Unified_V21_class["VG_avg"] 

Pre_21_Pack = Unified_V30_Pack["pre"]        # Defects before 6 months of release
Post_21_Pack=Unified_V30_Pack["post"]      # Defects after 6 months of release
FOUT_21_Pack=Unified_V30_Pack["FOUT_avg"]  # fan out (method calls)
MLOC_21_Pack=Unified_V30_Pack["MLOC_avg"]  # method line of code
NOM_21_Pack=Unified_V30_Pack["NOM_avg"]    # methods
NSM_21_Pack=Unified_V30_Pack["NSM_avg"]    # static methods
NOCU_21_Pack=Unified_V30_Pack["NOCU"]       #Number of files (compilation units)
VG_21_class=Unified_V21_class["VG_avg"]     # VG

# %%
Pre_30_class=Unified_V30_class["pre"]        # Defects before 6 months of release
Post_30_class=Unified_V30_class["post"]      # Defects after 6 months of release
FOUT_30_class=Unified_V30_class["FOUT_avg"]  # fan out (method calls)
MLOC_30_class=Unified_V30_class["MLOC_avg"]  # method line of code
NOM_30_class=Unified_V30_class["NOM_avg"]    # methods
NSM_30_class=Unified_V30_class["NSM_avg"]    # static methods
NOT_30_class=Unified_V30_class["NOT"]        # classes
NOI_30_class=Unified_V30_class["NOI"]        # Interfaces
TLOC_30_class=Unified_V30_class["TLOC"]      # total lines of code
ACD_30_class=Unified_V30_class["ACD"]        # Anonymous type declarations
VG_30_class=Unified_V30_class["VG_avg"] 

Pre_30_Pack = Unified_V21_Pack["pre"]        # Defects before 6 months of release
Post_30_Pack=Unified_V21_Pack["post"]      # Defects after 6 months of release
FOUT_30_Pack=Unified_V21_Pack["FOUT_avg"]  # fan out (method calls)
MLOC_30_Pack=Unified_V21_Pack["MLOC_avg"]  # method line of code
NOM_30_Pack=Unified_V21_Pack["NOM_avg"]    # methods
NSM_30_Pack=Unified_V21_Pack["NSM_avg"]    # static methods
NOCU_30_Pack=Unified_V21_Pack["NOCU"]       #Number of files (compilation units)
VG_30_class=Unified_V30_class["VG_avg"]       # VG

# %%
NOCU_20_Pack

# %%
for i in TLOC_20_class:
  print(i)

# %% [markdown]
# # The common files over the datasets

# %%
Unified_V20_class["filename"]

bugs = {}
i = 0
for file in Unified_V20_class["filename"]:
  bugs[file] = [Unified_V20_class["pre"][i], Unified_V20_class["pre"][i]]
  i = i + 1

# for rec in bugs:
#   print(rec)
print(bugs, "\n")
# Out:
# {'/org.eclipse.jdt.junit/src/org/eclipse/jdt/internal/junit/launcher/JUnitBaseLaunchConfiguration.java': [1.0, 1.0], '/org.eclipse.jdt.junit/src/org/eclipse/jdt/internal/junit/launcher/JUnitLaunchConfiguration.java': [1.0, 1.0], '/org.eclipse.jdt.junit/src/org/eclipse/jdt/internal/junit/launcher/JUnitLaunchConfigurationTab.java': [0.0, 0.0], '/org.eclipse.jdt.junit/src/org/eclipse/jdt/internal/junit/launcher/JUnitLaunchShortcut.java': [2.0, 2.0], '/org.eclipse.jdt.junit/src/org/eclipse/jdt/internal/junit/launcher/JUnitMainTab.java': [2.0, 2.0], '/org.eclipse.jdt.junit/src/org/eclipse/jdt/internal/junit/launcher/JUnitTabGroup.java': [1.0, 1.0], '/org.eclipse.jdt.junit/src/org/eclipse/jdt/internal/junit/launcher/TestSelectionDialog.java': [0.0, 0.0], '/org.eclipse.jdt.junit/src/org/eclipse/jdt/internal/junit/runner/ITestRunListener.java': [0.0, 0.0], '/org.eclipse.jdt.junit/src/org/eclipse/jdt/internal/junit/runner/MessageIds.java': [1.0, 1.0], '/org.eclipse.jdt.junit/src/org/eclipse/j
# ...
